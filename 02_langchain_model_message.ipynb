# %% [markdown]
# # openapi key 확인
# - pip install -U python-dotenv

# %%
from dotenv import load_dotenv
import os

load_dotenv()
api_key = os.environ["OPENAI_API_KEY"]
# api_key

# %%
from langchain_openai import ChatOpenAI
llm = ChatOpenAI(model="gpt-4o", api_key=api_key)
llm
# Out:
# ChatOpenAI(client=<openai.resources.chat.completions.Completions object at 0x000002A67979EA80>, async_client=<openai.resources.chat.completions.AsyncCompletions object at 0x000002A6797CC860>, root_client=<openai.OpenAI object at 0x000002A67698AF30>, root_async_client=<openai.AsyncOpenAI object at 0x000002A67979EAE0>, model_name='gpt-4o', model_kwargs={}, openai_api_key=SecretStr('**********'))

# %% [markdown]
# - langchain을 ChatOpenAI()객체를 통해서 질문하기

# %%
# 메시지는 list, list의 요소는 tuple 구조로
messages = [
    ("system", "당신은 서울의 음시과 문화 전문가 입니다."),
    ("human", "서울을 대표하는 음식을 맛볼 수 있는 레스토랑 5개를 추천해줘.")
]

res = llm.invoke(messages)

# %%
res
# Out:
# AIMessage(content='서울에서 전통적인 한국 음식을 맛볼 수 있는 레스토랑을 추천해드리겠습니다. 이곳들은 서울을 대표하는 다양한 음식을 제공합니다.\n\n1. **명동교자**: 칼국수로 유명한 곳으로, 진한 육수와 쫄깃한 면발이 일품입니다. 특히 만두도 함께 즐기기에 좋습니다.\n\n2. **한정식집 – 궁**: 한옥 스타일의 인테리어로 전통적인 분위기를 살린 곳입니다. 다양한 반찬과 함께 한식을 정갈하게 즐길 수 있는 한정식 코스를 제공합니다.\n\n3. **토속촌 삼계탕**: 삼계탕 전문점으로, 부드러운 닭고기와 깊은 맛의 국물이 특징입니다. 특히, 건강을 생각하신다면 인삼이 들어간 삼계탕을 추천합니다.\n\n4. **깡통시장 할매집**: 비빔밥과 전을 맛볼 수 있는 전통 시장의 매력을 느낄 수 있는 곳입니다. 다양한 전통 음식을 저렴한 가격에 즐길 수 있습니다.\n\n5. **광장시장 순희네 빈대떡**: 전통 시장 내에서 빈대떡과 함께 막걸리를 즐길 수 있는 곳입니다. 특히 빈대떡의 바삭하고 고소한 맛이 일품입니다.\n\n이 외에도 서울에는 다양한 맛집들이 많이 있으니, 각자의 취향에 맞는 곳을 찾아보는 것도 좋은 경험이 될 것입니다.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 327, 'prompt_tokens': 44, 'total_tokens': 371, 'completion_tokens_details': {'audio_tokens': None, 'reasoning_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_a7d06e42a7', 'finish_reason': 'stop', 'logprobs': None}, id='run-bf3308a6-86c1-4d7a-99e2-e7ed26851d2c-0', usage_metadata={'input_tokens': 44, 'output_tokens': 327, 'total_tokens': 371, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 0}})

# %%
res.content
# Out:
# '서울에서 전통적인 한국 음식을 맛볼 수 있는 레스토랑을 추천해드리겠습니다. 이곳들은 서울을 대표하는 다양한 음식을 제공합니다.\n\n1. **명동교자**: 칼국수로 유명한 곳으로, 진한 육수와 쫄깃한 면발이 일품입니다. 특히 만두도 함께 즐기기에 좋습니다.\n\n2. **한정식집 – 궁**: 한옥 스타일의 인테리어로 전통적인 분위기를 살린 곳입니다. 다양한 반찬과 함께 한식을 정갈하게 즐길 수 있는 한정식 코스를 제공합니다.\n\n3. **토속촌 삼계탕**: 삼계탕 전문점으로, 부드러운 닭고기와 깊은 맛의 국물이 특징입니다. 특히, 건강을 생각하신다면 인삼이 들어간 삼계탕을 추천합니다.\n\n4. **깡통시장 할매집**: 비빔밥과 전을 맛볼 수 있는 전통 시장의 매력을 느낄 수 있는 곳입니다. 다양한 전통 음식을 저렴한 가격에 즐길 수 있습니다.\n\n5. **광장시장 순희네 빈대떡**: 전통 시장 내에서 빈대떡과 함께 막걸리를 즐길 수 있는 곳입니다. 특히 빈대떡의 바삭하고 고소한 맛이 일품입니다.\n\n이 외에도 서울에는 다양한 맛집들이 많이 있으니, 각자의 취향에 맞는 곳을 찾아보는 것도 좋은 경험이 될 것입니다.'

# %%
print(res.content)
# Out:
# 서울에서 전통적인 한국 음식을 맛볼 수 있는 레스토랑을 추천해드리겠습니다. 이곳들은 서울을 대표하는 다양한 음식을 제공합니다.
#
# 1. **명동교자**: 칼국수로 유명한 곳으로, 진한 육수와 쫄깃한 면발이 일품입니다. 특히 만두도 함께 즐기기에 좋습니다.
#
# 2. **한정식집 – 궁**: 한옥 스타일의 인테리어로 전통적인 분위기를 살린 곳입니다. 다양한 반찬과 함께 한식을 정갈하게 즐길 수 있는 한정식 코스를 제공합니다.
#
# 3. **토속촌 삼계탕**: 삼계탕 전문점으로, 부드러운 닭고기와 깊은 맛의 국물이 특징입니다. 특히, 건강을 생각하신다면 인삼이 들어간 삼계탕을 추천합니다.
#
# 4. **깡통시장 할매집**: 비빔밥과 전을 맛볼 수 있는 전통 시장의 매력을 느낄 수 있는 곳입니다. 다양한 전통 음식을 저렴한 가격에 즐길 수 있습니다.
#
# 5. **광장시장 순희네 빈대떡**: 전통 시장 내에서 빈대떡과 함께 막걸리를 즐길 수 있는 곳입니다. 특히 빈대떡의 바삭하고 고소한 맛이 일품입니다.
#
# 이 외에도 서울에는 다양한 맛집들이 많이 있으니, 각자의 취향에 맞는 곳을 찾아보는 것도 좋은 경험이 될 것입니다.

# %% [markdown]
# # batch

# %%
messages = [
    [("system", "당신은 서울의 음식 전문가입니다."), 
        ("human", "서울 광장시장에서 먹을 만한 길거리 음식들을 소개해 주세요")],
    [("system", "당신은 서울의 문화 전문가입니다."), 
         ("human", "서울에서 데이트할 때 가 볼 만한 분위기 좋은 곳들을 알려 주세요")] 
]

responses = llm.batch(messages)

# %%
responses
# Out:
# [AIMessage(content='서울 광장시장은 다양한 길거리 음식으로 유명한 장소입니다. 여기서 꼭 맛봐야 할 몇 가지 음식을 소개해드리겠습니다.\n\n1. **빈대떡**: 두툼한 녹두전으로, 바삭하고 고소한 맛이 일품입니다. 막걸리와 함께 먹으면 더욱 좋습니다.\n\n2. **마약김밥**: 한 입 크기의 작은 김밥으로, 간장 소스에 찍어 먹으면 중독적인 맛을 자랑합니다.\n\n3. **쫄면**: 매콤달콤한 양념에 비벼 먹는 쫄깃한 면 요리로, 아삭한 야채와 함께 먹으면 더욱 맛있습니다.\n\n4. **칼국수**: 손으로 직접 뽑은 면발과 진한 국물이 매력적인 음식입니다. 다양한 해산물이나 고기와 함께 즐길 수 있습니다.\n\n5. **순대**: 돼지의 창자에 당면과 여러 재료를 넣어 만든 음식으로, 쫄깃한 식감과 고소한 맛이 특징입니다.\n\n6. **호떡**: 달콤한 설탕과 견과류가 들어있는 뜨거운 팬케이크로, 겨울철에는 더욱 인기가 많습니다.\n\n7. **떡볶이**: 매콤달콤한 양념에 쫄깃한 떡과 어묵을 함께 볶아 만든 음식으로, 한국의 대표적인 길거리 음식입니다.\n\n이 외에도 광장시장에는 다양한 전통 음식과 간식들이 많으니, 방문하셔서 여러 가지를 시도해 보세요!', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 369, 'prompt_tokens': 36, 'total_tokens': 405, 'completion_tokens_details': {'audio_tokens': None, 'reasoning_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_45c6de4934', 'finish_reason': 'stop', 'logprobs': None}, id='run-ded54876-24f2-4534-8966-119e1776b198-0', usage_metadata={'input_tokens': 36, 'output_tokens': 369, 'total_tokens': 405, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 0}}),
#  AIMessage(content='서울은 다양한 매력을 가진 도시로, 데이트하기 좋은 장소가 많이 있습니다. 여기 몇 가지 추천 장소를 소개합니다.\n\n1. **한강공원**: 한강을 따라 여러 공원이 조성되어 있어 자전거를 타거나 피크닉을 즐기기에 좋습니다. 특히 여의도 한강공원에서는 야경이 아름답습니다.\n\n2. **남산 서울타워**: 서울의 전경을 한눈에 볼 수 있는 명소입니다. 케이블카를 타고 올라가는 재미도 있고, 타워에서 연인과 함께 자물쇠를 걸어 사랑을 약속할 수도 있습니다.\n\n3. **북촌 한옥마을**: 전통 한옥이 모여 있는 이곳은 한국의 옛 정취를 느낄 수 있는 장소로, 조용히 산책하기 좋습니다. 작은 카페와 갤러리도 많아 둘러보기 좋습니다.\n\n4. **이태원**: 다양한 음식점과 바가 있는 이태원은 이국적인 분위기를 즐길 수 있는 곳입니다. 다양한 문화가 공존하는 거리를 걸으며 색다른 데이트를 즐길 수 있습니다.\n\n5. **가로수길**: 세련된 카페와 패션 숍이 모여 있는 곳으로, 쇼핑과 맛있는 음식을 함께 즐기기에 좋습니다. 분위기 있는 골목길에서 여유로운 시간을 보낼 수 있습니다.\n\n6. **서울숲**: 도심 속 자연을 느낄 수 있는 곳으로, 산책로나 자전거 도로가 잘 조성되어 있습니다. 특히 가을에는 단풍이 아름다워 더욱 매력적입니다.\n\n7. **홍대**: 젊고 활기찬 분위기의 홍대는 스트리트 퍼포먼스와 다양한 예술 활동이 활발한 곳입니다. 개성 있는 카페와 레스토랑도 많아 데이트에 적합합니다.\n\n8. **잠실 롯데월드몰**: 실내 테마파크인 롯데월드와 복합 쇼핑몰, 서울스카이 전망대 등을 함께 즐길 수 있어 다양한 데이트 코스를 계획할 수 있습니다.\n\n9. **창덕궁 후원**: 경복궁과는 또 다른 매력을 가진 창덕궁의 후원은 자연과 어우러진 아름다운 정원으로, 사전 예약을 통해 한적하게 둘러볼 수 있습니다.\n\n각 장소마다 고유의 매력이 있으니, 연인과 함께 원하는 분위기에 맞춰 즐겨보세요!', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 550, 'prompt_tokens': 37, 'total_tokens': 587, 'completion_tokens_details': {'audio_tokens': None, 'reasoning_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_a7d06e42a7', 'finish_reason': 'stop', 'logprobs': None}, id='run-5cff78f9-1934-40b1-bac1-408c253060fe-0', usage_metadata={'input_tokens': 37, 'output_tokens': 550, 'total_tokens': 587, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 0}})]

# %%
for response in responses:
    print(response.content, "\n")
# Out:
# 서울 광장시장은 다양한 길거리 음식으로 유명한 장소입니다. 여기서 꼭 맛봐야 할 몇 가지 음식을 소개해드리겠습니다.
#
# 1. **빈대떡**: 두툼한 녹두전으로, 바삭하고 고소한 맛이 일품입니다. 막걸리와 함께 먹으면 더욱 좋습니다.
#
# 2. **마약김밥**: 한 입 크기의 작은 김밥으로, 간장 소스에 찍어 먹으면 중독적인 맛을 자랑합니다.
#
# 3. **쫄면**: 매콤달콤한 양념에 비벼 먹는 쫄깃한 면 요리로, 아삭한 야채와 함께 먹으면 더욱 맛있습니다.
#
# 4. **칼국수**: 손으로 직접 뽑은 면발과 진한 국물이 매력적인 음식입니다. 다양한 해산물이나 고기와 함께 즐길 수 있습니다.
#
# 5. **순대**: 돼지의 창자에 당면과 여러 재료를 넣어 만든 음식으로, 쫄깃한 식감과 고소한 맛이 특징입니다.
#
# 6. **호떡**: 달콤한 설탕과 견과류가 들어있는 뜨거운 팬케이크로, 겨울철에는 더욱 인기가 많습니다.
#
# 7. **떡볶이**: 매콤달콤한 양념에 쫄깃한 떡과 어묵을 함께 볶아 만든 음식으로, 한국의 대표적인 길거리 음식입니다.
#
# 이 외에도 광장시장에는 다양한 전통 음식과 간식들이 많으니, 방문하셔서 여러 가지를 시도해 보세요!
#
# 서울은 다양한 매력을 가진 도시로, 데이트하기 좋은 장소가 많이 있습니다. 여기 몇 가지 추천 장소를 소개합니다.
#
# 1. **한강공원**: 한강을 따라 여러 공원이 조성되어 있어 자전거를 타거나 피크닉을 즐기기에 좋습니다. 특히 여의도 한강공원에서는 야경이 아름답습니다.
#
# 2. **남산 서울타워**: 서울의 전경을 한눈에 볼 수 있는 명소입니다. 케이블카를 타고 올라가는 재미도 있고, 타워에서 연인과 함께 자물쇠를 걸어 사랑을 약속할 수도 있습니다.
#
# 3. **북촌 한옥마을**: 전통 한옥이 모여 있는 이곳은 한국의 옛 정취를 느낄 수 있는 장소로, 조용히 산책하기 좋습니다. 작은 카페와 갤러리도 많아 둘러보기 좋습니다.
#
# 4. **이태원**: 다양한 음식점과 바가 있는 이태원은 이국적인 분위기를 즐길 수 있는 곳입니다. 다양한 문화가 공존하는 거리를 걸으며 색다른 데이트를 즐길 수 있습니다.
#
# 5. **가로수길**: 세련된 카페와 패션 숍이 모여 있는 곳으로, 쇼핑과 맛있는 음식을 함께 즐기기에 좋습니다. 분위기 있는 골목길에서 여유로운 시간을 보낼 수 있습니다.
#
# 6. **서울숲**: 도심 속 자연을 느낄 수 있는 곳으로, 산책로나 자전거 도로가 잘 조성되어 있습니다. 특히 가을에는 단풍이 아름다워 더욱 매력적입니다.
#
# 7. **홍대**: 젊고 활기찬 분위기의 홍대는 스트리트 퍼포먼스와 다양한 예술 활동이 활발한 곳입니다. 개성 있는 카페와 레스토랑도 많아 데이트에 적합합니다.
#
# 8. **잠실 롯데월드몰**: 실내 테마파크인 롯데월드와 복합 쇼핑몰, 서울스카이 전망대 등을 함께 즐길 수 있어 다양한 데이트 코스를 계획할 수 있습니다.
#
# 9. **창덕궁 후원**: 경복궁과는 또 다른 매력을 가진 창덕궁의 후원은 자연과 어우러진 아름다운 정원으로, 사전 예약을 통해 한적하게 둘러볼 수 있습니다.
#
# 각 장소마다 고유의 매력이 있으니, 연인과 함께 원하는 분위기에 맞춰 즐겨보세요!

# %% [markdown]
# Async vs Sync

# %%
llm = ChatOpenAI(model="gpt-4o", api_key=api_key)
messages = [
    ("system", "당신은 서울의 음시과 문화 전문가 입니다."),
    ("human", "서울을 대표하는 음식을 맛볼 수 있는 레스토랑 5개를 추천해줘.")
]

# %%
import asyncio
import time

async def invoke_async(llm, messages):
    response = await llm.ainvoke(messages)
    print(response.content)

async def invoke_parallel(llm, messages):
    tasks = [invoke_async(llm, messages) for _ in range(10)]
    await asyncio.gather(*tasks)

# %%
print("Async")
start = time.perf_counter()
await invoke_parallel(llm, messages)
end = time.perf_counter()
print(f"Elapsed time: {end - start:.2f} seconds")
# Out:
# Async
# 서울은 다양한 전통 음식과 현대적인 퓨전 요리를 즐길 수 있는 곳입니다. 다음은 서울을 대표하는 음식을 맛볼 수 있는 레스토랑 5곳입니다:
#
# 1. **깡계치**:
#    - 이곳은 삼계탕으로 유명한 곳입니다. 전통적인 방식으로 끓인 삼계탕을 맛볼 수 있으며, 특히 여름철에 보양식으로 인기가 많습니다.
#
# 2. **명동교자**:
#    - 명동에 위치한 이 식당은 칼국수와 만두로 유명합니다. 진한 육수와 쫄깃한 면발, 그리고 고기와 야채가 가득한 만두가 인기 메뉴입니다.
#
# 3. **토속촌 삼계탕**:
#    - 경복궁 근처에 위치한 이곳은 고급스러운 삼계탕을 제공합니다. 한옥 스타일의 인테리어로 전통적인 분위기에서 식사를 즐길 수 있습니다.
#
# 4. **광장시장**:
#    - 전통 시장에서 다양한 한국 음식을 맛볼 수 있는 곳입니다. 빈대떡, 마약김밥, 떡볶이 등 다양한 길거리 음식을 저렴한 가격에 즐길 수 있습니다.
#
# 5. **정식당**:
#    - 한식의 현대적인 해석을 맛볼 수 있는 고급 레스토랑으로, 다양한 코스 요리를 제공합니다. 전통적인 재료와 현대적인 조리법을 결합한 메뉴가 특징입니다.
#
# 이 레스토랑들은 서울의 다양한 맛과 음식을 경험할 수 있는 좋은 선택지입니다. 방문 전에 예약을 확인하는 것이 좋습니다.
# 서울에는 다양한 전통 음식과 현대적인 해석을 더한 한식을 맛볼 수 있는 훌륭한 레스토랑이 많이 있습니다. 다음은 서울을 대표하는 음식을 맛볼 수 있는 레스토랑 5곳입니다:
#
# 1. **광장시장**:
#    - 광장시장은 다양한 전통 한국 음식을 맛볼 수 있는 장소로, 특히 빈대떡, 마약김밥, 육회 등 다양한 길거리 음식을 맛볼 수 있습니다. 시장 내 여러 점포에서 신선한 재료로 만든 음식을 즐길 수 있습니다.
#
# 2. **한정식집 "별궁"**:
#    - 종로구에 위치한 별궁은 전통 한정식을 현대적으로 해석하여 제공하는 레스토랑입니다. 다양한 반찬과 함께 제공되는 코스 요리로 한국의 전통적인 식문화를 체험할 수 있습니다.
#
# 3. **백년옥**:
#    - 서초구에 위치한 백년옥은 전통 두부 요리 전문점으로, 특히 순두부와 두부전골이 유명합니다. 한국 두부 요리의 진수를 맛볼 수 있는 곳입니다.
#
# 4. **고려삼계탕**:
#    - 종로구에 위치한 고려삼계탕은 서울에서 가장 유명한 삼계탕 전문점 중 하나로, 진하고 깊은 맛의 국물과 함께 인삼과 대추가 들어간 삼계탕을 맛볼 수 있습니다.
#
# 5. **명동교자**:
#    - 명동에 위치한 명동교자는 칼국수 전문점으로, 진한 육수와 쫄깃한 면발의 칼국수가 대표 메뉴입니다. 전통적인 한국식 국수를 맛보고 싶다면 이곳을 추천합니다.
#
# 이 외에도 서울에는 다양한 한식 레스토랑이 많으니, 방문 시 다양한 음식 문화를 체험해 보시기 바랍니다.
# 서울은 다양한 전통과 현대적인 요리로 가득한 도시입니다. 여기 서울을 대표하는 음식을 맛볼 수 있는 레스토랑 다섯 곳을 추천드립니다.
#
# 1. **광장시장** - 전통 시장인 광장시장은 한국의 길거리 음식을 맛볼 수 있는 최고의 장소 중 하나입니다. 특히 빈대떡, 마약김밥, 육회비빔밥 등을 맛볼 수 있습니다.
#
# 2. **백년옥** - 순두부 전문점으로, 서울에서 가장 유명한 순두부 요리 중 하나를 제공합니다. 부드럽고 신선한 순두부를 다양한 스타일로 즐길 수 있습니다.
#
# 3. **토속촌 삼계탕** - 한국의 대표적인 보양식인 삼계탕을 맛볼 수 있는 곳입니다. 토속촌 삼계탕은 전통적인 방식으로 요리된 삼계탕으로 유명하며, 한국의 건강식을 경험하기 좋습니다.
#
# 4. **명동교자** - 칼국수와 만두로 유명한 명동교자는 현지인과 관광객 모두에게 사랑받는 곳입니다. 진한 국물과 쫄깃한 면발이 일품입니다.
#
# 5. **한우마을** - 한국의 고급 소고기인 한우를 맛볼 수 있는 곳으로, 다양한 부위의 고기를 구워 먹을 수 있습니다. 한국식 바비큐를 경험하고 싶다면 추천드립니다.
#
# 이 레스토랑들은 각각 서울의 대표적인 맛과 문화를 보여주는 곳이니 꼭 방문해보세요!
# 서울은 다양한 음식을 맛볼 수 있는 도시이며, 전통 한식부터 현대적인 퓨전 요리까지 다양한 선택지가 있습니다. 서울을 대표하는 음식을 맛볼 수 있는 레스토랑 다섯 곳을 추천드리겠습니다.
#
# 1. **고려삼계탕**: 삼계탕은 서울을 대표하는 보양 음식 중 하나입니다. 고려삼계탕은 오랜 전통을 자랑하며, 부드럽고 진한 국물의 삼계탕을 맛볼 수 있는 곳입니다.
#
# 2. **명동교자**: 서울에서는 칼국수를 꼭 맛봐야 합니다. 명동교자는 칼국수와 만두로 유명하며, 진한 육수와 쫄깃한 면발의 조화를 경험할 수 있습니다.
#
# 3. **백년옥**: 순두부찌개는 한국의 대표적인 찌개 요리 중 하나입니다. 백년옥은 신선한 순두부와 깊은 맛의 찌개로 유명하며, 다양한 반찬과 함께 즐길 수 있습니다.
#
# 4. **한일관**: 불고기는 한국을 대표하는 바비큐 요리입니다. 한일관은 오랜 전통을 가진 한식당으로, 고급스러운 불고기와 함께 다양한 한식을 경험할 수 있습니다.
#
# 5. **광장시장**: 비록 레스토랑은 아니지만, 광장시장은 서울의 전통적인 길거리 음식을 맛볼 수 있는 최고의 장소입니다. 마약김밥, 빈대떡, 순대볶음 등 다양한 전통 음식을 즐길 수 있습니다.
#
# 이곳들에서 서울의 다양한 맛과 문화를 경험하시길 바랍니다!
# 서울에는 다양한 전통과 현대적인 음식을 맛볼 수 있는 레스토랑이 많습니다. 다음은 서울을 대표하는 음식을 맛볼 수 있는 다섯 곳의 레스토랑 추천입니다.
#
# 1. **광장시장** - 전통 시장이지만 서울에서 가장 유명한 먹거리 중 하나인 빈대떡과 마약김밥을 맛볼 수 있습니다. 다양한 전통 한국 음식을 한 자리에서 경험할 수 있는 좋은 장소입니다.
#
# 2. **토속촌 삼계탕** - 경복궁 근처에 위치한 이곳은 삼계탕으로 유명합니다. 진한 국물과 부드러운 닭고기가 일품이며, 한국의 대표적인 보양식을 경험할 수 있습니다.
#
# 3. **미쉐린 가이드 선정 한식당 '광주회관'** - 서울의 중심부에 위치한 이곳에서는 비빔밥과 전통 한식을 현대적인 감각으로 재해석한 요리를 즐길 수 있습니다. 특히 전주 비빔밥이 유명합니다.
#
# 4. **삼청동 수제비** - 삼청동 거리에 위치한 이곳은 전통적인 수제비를 맛볼 수 있는 곳으로, 담백한 맛과 쫄깃한 면발이 특징입니다. 한국의 가정식 요리를 경험하고 싶다면 추천합니다.
#
# 5. **한옥마을 '한국의 집'** - 전통 한옥 건물에서 한국의 전통 한정식을 즐길 수 있는 곳입니다. 다양한 전통 공연도 함께 관람할 수 있어 한국 문화를 깊이 있게 체험할 수 있습니다.
#
# 각 레스토랑은 서울의 독특한 식문화를 체험할 수 있는 장소들로, 전통적인 맛뿐만 아니라 현대적인 감각을 가미한 음식까지 다양하게 즐길 수 있습니다.
# 서울은 다양한 전통 음식과 현대적인 요리로 유명한 도시입니다. 서울을 대표하는 음식을 맛볼 수 있는 레스토랑 몇 군데를 추천해드리겠습니다.
#
# 1. **명동교자**: 이곳은 칼국수와 만두로 유명합니다. 진한 국물과 쫄깃한 면발, 그리고 고기와 채소가 가득한 만두가 일품입니다. 명동에 위치해 있어 접근성도 좋습니다.
#
# 2. **광장시장**: 전통적인 한국 음식을 다양하게 맛볼 수 있는 시장입니다. 특히 빈대떡, 마약김밥, 떡볶이 등 길거리 음식을 경험해보기에 좋은 장소입니다.
#
# 3. **가온**: 서울에서 미슐랭 3스타를 받은 한식 레스토랑으로, 전통 한식을 현대적으로 재해석한 요리를 제공합니다. 고급스럽고 정교한 한식을 경험하고 싶다면 추천합니다.
#
# 4. **한미리**: 한정식 전문점으로, 다양한 한식 요리를 한꺼번에 맛볼 수 있는 곳입니다. 정갈하게 차려진 상차림으로 한식의 진수를 느낄 수 있습니다.
#
# 5. **정식당**: 미슐랭 2스타를 받은 레스토랑으로, 전통 한식을 모던하게 재해석한 메뉴를 제공합니다. 창의적인 요리와 세련된 분위기를 즐기실 수 있습니다.
#
# 이 레스토랑들은 각기 다른 매력을 가지고 있어, 서울의 다양한 음식 문화를 경험하는 데 좋은 선택이 될 것입니다.
# 서울은 다양한 전통과 현대적인 음식을 즐길 수 있는 곳으로 유명합니다. 다음은 서울을 대표하는 음식을 맛볼 수 있는 레스토랑 5곳입니다.
#
# 1. **광장시장** - 비록 특정 레스토랑은 아니지만, 광장시장은 전통적인 한국 음식을 맛볼 수 있는 곳으로 유명합니다. 특히 육회, 빈대떡, 마약김밥 등을 꼭 맛보세요.
#
# 2. **봉추찜닭** - 서울에서 찜닭을 맛보고 싶다면 봉추찜닭을 추천합니다. 감칠맛 나는 양념과 부드러운 닭고기가 일품입니다.
#
# 3. **명동교자** - 명동교자는 칼국수와 만두로 유명한 곳입니다. 특히 육수가 진하고 깊은 맛이 나며, 고기의 풍미를 잘 살린 만두가 인기 있습니다.
#
# 4. **한정식집 한국집** - 전통 한정식을 경험하고 싶다면 한국집을 추천합니다. 다양한 반찬과 함께 정갈하게 차려진 한정식을 통해 한국의 전통적인 식문화를 체험할 수 있습니다.
#
# 5. **이천쌀밥집** - 서울의 인기 있는 한식당 중 하나로, 이천의 고급 쌀을 사용한 쌀밥과 함께 다양한 반찬을 맛볼 수 있는 곳입니다. 깔끔하고 정성스러운 한식이 일품입니다.
#
# 이 외에도 서울에는 다양한 음식을 즐길 수 있는 많은 레스토랑이 있으니, 방문 시 다양한 옵션을 탐색해 보세요.
# 서울은 다양한 전통 음식과 현대적인 요리가 공존하는 미식의 도시입니다. 서울을 대표하는 음식을 맛볼 수 있는 레스토랑 다섯 곳을 소개해드릴게요.
#
# 1. **광장시장** - 비록 레스토랑은 아니지만, 광장시장은 서울의 대표적인 전통 시장으로, 다양한 한국 전통 음식을 맛볼 수 있는 곳입니다. 빈대떡, 마약김밥, 육회 등 다양한 길거리 음식을 즐길 수 있습니다.
#
# 2. **한국집** - 서울 종로구에 위치한 한국집은 전통 한식을 제공하는 곳으로, 특히 비빔밥이 유명합니다. 고즈넉한 분위기에서 정통 한식을 맛볼 수 있습니다.
#
# 3. **명동교자** - 칼국수로 유명한 명동교자는 서울의 대표적인 맛집 중 하나입니다. 진한 육수와 쫄깃한 면발의 칼국수는 물론, 함께 제공되는 김치도 별미입니다.
#
# 4. **우래옥** - 1946년에 개업한 오래된 냉면 전문점으로, 평양냉면을 맛볼 수 있는 곳입니다. 고기 육수의 깊은 맛과 메밀면의 조화가 일품입니다.
#
# 5. **진주회관** - 서울 중구에 위치한 진주회관은 콩나물국밥으로 유명합니다. 한국 전통의 맛을 제대로 느낄 수 있는 곳으로, 해장국으로도 인기가 많습니다.
#
# 이곳들은 서울의 다양한 전통 음식을 경험할 수 있는 대표적인 장소들입니다. 각기 다른 매력을 가진 이곳들을 방문해 보세요!
# 서울에는 다양한 전통 음식과 현대적인 변형을 경험할 수 있는 레스토랑이 많이 있습니다. 서울을 대표하는 음식을 맛볼 수 있는 몇 가지 추천 레스토랑은 다음과 같습니다.
#
# 1. **삼청동 수제비**:
#    - 위치: 종로구 삼청동
#    - 추천 메뉴: 전통적인 수제비와 칼국수
#    - 특징: 고즈넉한 삼청동에서 전통적인 한식을 맛볼 수 있는 곳으로, 손으로 직접 만든 수제비가 유명합니다.
#
# 2. **명동 교자**:
#    - 위치: 중구 명동
#    - 추천 메뉴: 칼국수, 만두
#    - 특징: 명동 교자는 칼국수와 만두로 유명하며, 특히 진한 육수와 쫄깃한 면발이 매력적입니다. 항상 많은 사람들이 줄을 서는 인기 맛집입니다.
#
# 3. **조선옥**:
#    - 위치: 중구 을지로
#    - 추천 메뉴: 불고기, 갈비
#    - 특징: 오래된 전통을 자랑하는 조선옥은 불고기의 풍미를 제대로 느낄 수 있는 곳으로, 숯불에 구운 고기의 맛이 일품입니다.
#
# 4. **토속촌 삼계탕**:
#    - 위치: 종로구 체부동
#    - 추천 메뉴: 삼계탕
#    - 특징: 토속촌은 진한 국물과 건강한 재료로 만든 삼계탕으로 유명하며, 특히 외국인 관광객들에게 인기가 많습니다.
#
# 5. **광장시장**:
#    - 위치: 종로구 종로
#    - 추천 메뉴: 빈대떡, 육회, 마약김밥
#    - 특징: 전통 시장인 광장시장은 다양한 한국 음식을 한 곳에서 맛볼 수 있는 곳으로, 특히 빈대떡과 육회가 유명합니다.
#
# 이 레스토랑들은 서울의 다양한 전통 음식을 경험할 수 있는 최고의 장소들입니다. 각기 다른 매력을 지닌 이곳들을 방문해보세요!
# 서울에는 다양한 전통 음식과 현대적인 해석이 가미된 요리를 맛볼 수 있는 멋진 레스토랑들이 많습니다. 다음은 서울을 대표하는 음식을 맛볼 수 있는 다섯 곳의 추천 레스토랑입니다.
#
# 1. **명동교자**:
#    - 위치: 중구 명동
#    - 대표 메뉴: 칼국수, 만두
#    - 설명: 명동교자는 서울에서 가장 유명한 칼국수 전문점 중 하나로, 깊고 진한 국물과 쫄깃한 면발이 특징입니다. 만두도 함께 즐길 수 있습니다.
#
# 2. **한미리**:
#    - 위치: 종로구 광화문
#    - 대표 메뉴: 한정식
#    - 설명: 한미리는 정갈하고 다양한 한정식을 맛볼 수 있는 곳으로, 전통 한식을 아름답게 담아내는 곳입니다. 한국의 고유한 맛과 멋을 경험할 수 있습니다.
#
# 3. **진진**:
#    - 위치: 마포구 연남동
#    - 대표 메뉴: 짜장면, 짬뽕
#    - 설명: 전통적인 중식 요리를 한국 스타일로 즐길 수 있는 곳으로, 깊은 맛의 짜장면과 매콤한 짬뽕이 인기입니다. 오래된 동네의 정취도 함께 느낄 수 있습니다.
#
# 4. **깡통집**:
#    - 위치: 용산구 이태원
#    - 대표 메뉴: 삼겹살, 돼지갈비
#    - 설명: 한국의 대표적인 구이 요리를 맛볼 수 있는 곳으로, 참숯에 구워진 삼겹살과 돼지갈비의 풍미를 제대로 즐길 수 있습니다.
#
# 5. **광장시장**:
#    - 위치: 종로구
#    - 대표 메뉴: 빈대떡, 마약김밥
#    - 설명: 광장시장은 다양한 한국 전통 음식을 한자리에서 맛볼 수 있는 전통 시장입니다. 특히 빈대떡과 마약김밥은 꼭 맛봐야 할 별미입니다.
#
# 이곳들은 서울의 다양한 음식을 경험할 수 있는 대표적인 장소들로, 전통적인 맛과 함께 현대적인 감각을 즐길 수 있습니다.
# Elapsed time: 6.58 seconds

# %%
print("Sync")
start = time.perf_counter()
for i in range(10):
    response = llm.invoke(messages)
    print(response.content)
    print()
end = time.perf_counter()
print(f"Elapsed time: {end - start:.2f} seconds")
# Out:
# Sync
# 서울은 다양한 음식을 맛볼 수 있는 곳으로 유명합니다. 다음은 서울을 대표하는 음식을 맛볼 수 있는 레스토랑 5곳을 추천드립니다:
#
# 1. **광장시장**:
#    - 광장시장은 전통적인 한국 음식을 맛볼 수 있는 곳으로 유명합니다. 특히, 빈대떡, 마약김밥, 순대, 그리고 육회를 맛볼 수 있습니다. 다양한 길거리 음식을 즐길 수 있는 시장의 활기찬 분위기도 놓치지 마세요.
#
# 2. **명동교자**:
#    - 명동에 위치한 이 식당은 칼국수로 유명합니다. 진한 육수에 쫄깃한 면발이 특징이며, 만두도 함께 즐길 수 있습니다. 오랜 전통을 자랑하는 만큼, 현지인과 관광객 모두에게 인기가 많습니다.
#
# 3. **토속촌삼계탕**:
#    - 경복궁 근처에 위치한 토속촌은 삼계탕으로 유명합니다. 인삼, 찹쌀, 대추 등을 넣어 푹 끓인 삼계탕은 특히 여름철 몸보신 음식으로 인기가 많습니다. 고풍스러운 한옥 분위기도 매력적입니다.
#
# 4. **유진식당**:
#    - 이곳은 전통적인 한식을 현대적으로 재해석한 요리로 유명합니다. 불고기, 비빔밥, 전 등 한국의 대표적인 음식을 깔끔하게 즐길 수 있습니다. 모던한 인테리어와 함께 식사를 즐기기에 좋습니다.
#
# 5. **한와담**:
#    - 한와담은 고급 한우를 맛볼 수 있는 곳으로, 특히 서울에서 한우구이를 경험하고 싶다면 추천합니다. 다양한 부위의 한우를 직접 구워 먹을 수 있으며, 신선한 재료와 정성스러운 서비스가 특징입니다.
#
# 이 레스토랑들은 서울의 풍부한 미식 문화를 경험할 수 있는 훌륭한 장소들입니다. 방문하셔서 서울의 맛을 만끽해보세요!
#
# 서울은 다양한 전통 음식과 현대적인 퓨전 요리를 즐길 수 있는 곳입니다. 서울을 대표하는 음식을 맛볼 수 있는 레스토랑 다섯 곳을 추천해드립니다.
#
# 1. **고려삼계탕**
#    - 위치: 종로구
#    - 대표 메뉴: 삼계탕
#    - 특징: 오랜 전통을 자랑하는 삼계탕 전문점으로, 진하고 깊은 국물 맛을 자랑합니다. 보양식으로 유명하여 현지인과 관광객 모두에게 인기가 많습니다.
#
# 2. **명동교자**
#    - 위치: 중구 명동
#    - 대표 메뉴: 칼국수, 만두
#    - 특징: 명동의 필수 방문지로 꼽히는 곳으로, 고소한 육수와 쫄깃한 면발의 칼국수와 직접 빚은 만두가 유명합니다.
#
# 3. **한우마을**
#    - 위치: 강남구
#    - 대표 메뉴: 한우구이
#    - 특징: 최고급 한우를 맛볼 수 있는 곳으로, 다양한 부위의 한우를 숯불에 구워 먹을 수 있습니다. 고급스러운 인테리어와 서비스로 특별한 날 방문하기 좋은 곳입니다.
#
# 4. **토속촌**
#    - 위치: 종로구
#    - 대표 메뉴: 삼계탕
#    - 특징: 전통 한옥 건물에서 식사를 즐길 수 있는 삼계탕 전문점입니다. 부드러운 닭고기와 약재가 어우러진 국물이 일품입니다.
#
# 5. **광장시장**
#    - 위치: 종로구
#    - 대표 메뉴: 빈대떡, 마약김밥, 육회
#    - 특징: 전통 시장으로 다양한 한국 음식을 저렴하게 맛볼 수 있는 곳입니다. 여러 포장마차에서 즉석에서 조리한 음식을 즐길 수 있으며, 한국의 길거리 음식을 체험하기에 좋습니다.
#
# 이 레스토랑들은 서울의 다양한 미식을 경험할 수 있는 좋은 선택지입니다. 방문 전에 영업 시간을 확인하고 가시는 것을 추천드립니다.
#
# 서울은 다양한 전통과 현대적인 음식을 즐길 수 있는 곳입니다. 서울을 대표하는 음식을 맛볼 수 있는 레스토랑 다섯 곳을 추천해드리겠습니다.
#
# 1. **명동교자** - 명동에 위치한 이곳은 칼국수와 만두로 유명합니다. 깊고 진한 육수와 쫄깃한 면발이 일품인 칼국수를 맛볼 수 있으며, 한국을 찾는 외국인 관광객들에게도 인기가 많습니다.
#
# 2. **한일관** - 1939년에 설립된 한일관은 전통적인 한식을 현대적으로 재해석한 음식을 제공합니다. 불고기와 냉면이 특히 유명하며, 깔끔한 인테리어 속에서 편안하게 식사할 수 있습니다.
#
# 3. **곰바위** - 삼계탕을 전문으로 하는 이곳은 진한 국물과 부드러운 닭고기로 인기가 많습니다. 여름 보양식으로 한국인들이 즐겨 찾는 삼계탕을 제대로 맛볼 수 있는 곳입니다.
#
# 4. **진진** - 마포구에 위치한 이곳은 깐풍기와 짜장면, 짬뽕 등 한국식 중화요리로 유명합니다. 특히 깐풍기는 바삭하면서도 매콤달콤한 소스로 많은 사랑을 받고 있습니다.
#
# 5. **광장시장** - 레스토랑은 아니지만, 한국 전통시장인 광장시장은 서울의 다양한 길거리 음식을 맛볼 수 있는 곳입니다. 특히 빈대떡, 순대, 마약김밥 등 다양한 한국 전통 음식을 경험할 수 있습니다.
#
# 이 레스토랑들은 각각의 독특한 매력과 전통적인 맛으로 서울을 대표하는 음식들을 제공하니 꼭 한번 방문해 보시길 추천합니다.
#
# 서울을 대표하는 음식을 맛볼 수 있는 레스토랑은 다양하지만, 몇 가지를 추천하자면 다음과 같습니다.
#
# 1. **광장시장**: 광장시장은 서울의 전통 시장으로, 다양한 한국 음식을 맛볼 수 있는 곳입니다. 특히 빈대떡, 마약김밥, 육회 등 전통적인 길거리 음식을 경험해보세요.
#
# 2. **한미리**: 전통 한정식을 경험하고 싶다면 한미리를 추천합니다. 이 레스토랑은 다양한 반찬과 함께 정성껏 준비된 한정식을 제공합니다. 특히, 한국의 전통적인 상차림을 경험할 수 있습니다.
#
# 3. **우래옥**: 평양냉면으로 유명한 우래옥은 오랜 전통을 자랑하는 냉면집입니다. 시원하고 깔끔한 육수와 쫄깃한 면발이 특징으로, 서울에서 냉면을 맛보고 싶다면 꼭 방문해보세요.
#
# 4. **진진**: 삼겹살과 같은 한국식 고기를 맛보고 싶다면 진진을 추천합니다. 고기를 직접 구워 먹는 재미와 함께 다양한 반찬들이 곁들여져 한국식 고기 문화를 체험할 수 있습니다.
#
# 5. **봉피양**: 갈비와 불고기로 유명한 봉피양은 품질 좋은 고기를 맛볼 수 있는 곳입니다. 갈비구이와 불고기를 전통적인 방식으로 구워 먹는 경험을 할 수 있습니다.
#
# 이 레스토랑들은 서울에서 한국 전통 음식을 대표적으로 맛볼 수 있는 곳들이니 방문해보시길 권합니다.
#
# 서울에서 서울을 대표하는 음식을 맛볼 수 있는 레스토랑 다섯 곳을 소개해드리겠습니다.
#
# 1. **명동교자**: 명동에 위치한 이곳은 칼국수로 유명합니다. 진한 육수에 쫄깃한 면발, 그리고 깊은 맛을 자랑하는 만두는 많은 사람들의 사랑을 받고 있습니다.
#
# 2. **광장시장**: 전통시장이지만, 다양한 한국 전통 음식을 맛볼 수 있는 곳입니다. 특히 빈대떡, 육회, 마약김밥 등이 유명합니다. 여러 가게를 돌아다니며 다양한 음식을 경험해보세요.
#
# 3. **한정식집 한국집**: 종로에 위치한 이곳은 전통 한정식을 경험할 수 있는 곳입니다. 다양한 반찬과 함께 나오는 정갈한 한식 요리를 즐길 수 있습니다. 한국 전통의 맛과 멋을 느낄 수 있습니다.
#
# 4. **토속촌삼계탕**: 경복궁 근처에 위치한 이곳은 삼계탕으로 유명합니다. 인삼과 각종 한약재로 맛을 낸 진한 국물과 부드러운 닭고기의 조화는 건강식으로도 인기가 높습니다.
#
# 5. **곰탕집 하동관**: 을지로에 위치한 이곳은 곰탕의 원조로 알려져 있습니다. 70년 이상의 전통을 자랑하며, 깊고 진한 국물과 부드러운 고기는 이곳의 대표 메뉴입니다.
#
# 이 레스토랑들은 서울의 대표적인 음식을 맛볼 수 있는 곳으로, 각기 다른 매력을 제공합니다. 방문하셔서 서울의 다양한 맛을 경험해보세요.
#
# 서울은 다양한 전통 음식과 현대적인 퓨전 요리를 즐길 수 있는 곳입니다. 다음은 서울을 대표하는 음식을 맛볼 수 있는 레스토랑 5곳입니다:
#
# 1. **광장시장:** 전통 시장이지만 '순희네 빈대떡' 같은 곳에서 전통 빈대떡과 마약김밥, 떡볶이 등을 맛볼 수 있습니다. 시장의 활기찬 분위기 속에서 다양한 길거리 음식을 즐길 수 있습니다.
#
# 2. **조선호텔 아리아:** 서울에서 한식 뷔페를 경험하고 싶다면 조선호텔의 아리아를 추천합니다. 다양한 한국 전통 요리와 함께 현대적인 해석을 더한 메뉴를 맛볼 수 있습니다.
#
# 3. **목포집:** 종로에 위치한 이곳은 전통 한정식을 전문으로 합니다. 특히 게장, 전복장 등 해산물 요리가 유명하며, 깔끔한 반찬들과 함께 정갈한 한식을 경험할 수 있습니다.
#
# 4. **산촌:** 인사동에 위치한 산촌은 전통 한정식을 제공하는 곳으로, 채식주의자에게도 적합합니다. 한옥 스타일의 인테리어와 함께 버섯 전골, 나물 비빔밥 등의 건강한 메뉴를 맛볼 수 있습니다.
#
# 5. **우래옥:** 을지로에 위치한 우래옥은 평양냉면으로 유명한 곳입니다. 오랜 전통을 자랑하며, 평양냉면 외에도 불고기와 같은 전통적인 한국 고기 요리도 제공합니다.
#
# 이곳들은 서울에서 전통적이면서도 대표적인 한국 음식을 경험할 수 있는 곳들입니다. 각 레스토랑마다 고유의 매력과 맛을 즐기실 수 있습니다.
#
# 서울은 다양한 전통과 현대적인 요리를 제공하는 도시로, 여러 레스토랑에서 서울을 대표하는 음식을 맛볼 수 있습니다. 여기 몇 가지 추천 장소입니다:
#
# 1. **명동교자** - 명동에 위치한 이 식당은 칼국수와 만두로 유명합니다. 부드러운 면발과 진한 육수의 칼국수는 서울을 대표하는 맛 중 하나입니다.
#
# 2. **깡통집** - 이곳은 삼겹살과 같은 한국식 바비큐를 즐길 수 있는 곳으로, 특히 신촌 지역에 위치한 지점이 인기가 많습니다. 질 좋은 고기와 함께 한국식 반찬을 곁들여 먹으면 더욱 맛있습니다.
#
# 3. **조선옥** - 을지로에 위치한 이곳은 불고기 전문점으로, 전통적인 방식으로 조리된 불고기를 맛볼 수 있습니다. 서울을 대표하는 고기 요리를 경험하기 좋은 장소입니다.
#
# 4. **평양면옥** - 서울에 여러 지점을 둔 이 식당은 냉면으로 유명합니다. 특히 평양식 냉면은 담백하고 깊은 육수 맛이 특징이며, 서울의 여름 별미로 잘 알려져 있습니다.
#
# 5. **광장시장** - 전통 시장인 광장시장 내에 위치한 다양한 음식점에서는 빈대떡, 육회, 마약김밥 등 서울의 길거리 음식을 맛볼 수 있습니다. 시장의 활기찬 분위기와 함께 다양한 음식을 즐길 수 있는 곳입니다.
#
# 각 장소는 서울의 고유한 맛과 분위기를 경험할 수 있는 곳이니, 방문하셔서 다양한 서울의 맛을 즐겨보세요!
#
# 서울은 다양한 전통과 현대적인 요리를 경험할 수 있는 도시입니다. 다음은 서울의 대표적인 음식을 맛볼 수 있는 레스토랑 5곳을 추천합니다.
#
# 1. **평양면옥**
#    - 위치: 중구 장충동
#    - 추천 요리: 냉면
#    - 설명: 평양냉면으로 유명한 곳으로, 담백하고 시원한 육수와 쫄깃한 면발이 일품입니다. 서울에서 평양냉면의 진수를 경험할 수 있는 곳입니다.
#
# 2. **토속촌**
#    - 위치: 종로구 체부동
#    - 추천 요리: 삼계탕
#    - 설명: 진하고 깊은 맛의 삼계탕으로 유명한 곳입니다. 한옥 스타일의 전통적인 분위기 속에서 건강한 한 끼를 즐길 수 있습니다.
#
# 3. **광장시장**
#    - 위치: 종로구 예지동
#    - 추천 요리: 빈대떡, 마약김밥
#    - 설명: 서울의 전통 시장으로, 다양한 길거리 음식을 맛볼 수 있습니다. 특히 빈대떡과 마약김밥은 꼭 시도해볼 만한 메뉴입니다.
#
# 4. **일미식당**
#    - 위치: 중구 명동
#    - 추천 요리: 김치찌개
#    - 설명: 진한 김치찌개로 유명한 식당으로, 다양한 해산물과 돼지고기가 들어가 깊고 풍부한 맛을 자랑합니다. 현지인들 사이에서 인기가 많습니다.
#
# 5. **무교동 북어국집**
#    - 위치: 중구 다동
#    - 추천 요리: 북어국
#    - 설명: 해장국으로 유명한 북어국을 맛볼 수 있는 곳입니다. 오랜 전통을 자랑하며, 깊고 시원한 국물 맛이 특징입니다.
#
# 이 레스토랑들은 서울의 독특한 맛과 문화를 경험할 수 있는 곳들로, 각기 다른 매력을 지니고 있습니다. 즐거운 미식 탐험 되시길 바랍니다!
#
# 서울에는 다양한 전통 음식과 현대적인 퓨전 요리를 제공하는 멋진 레스토랑이 많이 있습니다. 서울을 대표하는 음식을 맛볼 수 있는 5개의 레스토랑을 소개해드리겠습니다.
#
# 1. **광장시장** - 전통적인 한국 길거리 음식을 경험하고 싶다면 광장시장을 추천합니다. 이곳에서는 빈대떡, 마약김밥, 육회 등 다양한 전통 음식을 맛볼 수 있습니다. 시장 내 여러 포장마차에서 신선한 음식을 즐길 수 있습니다.
#
# 2. **한복남** - 한정식을 경험하고 싶다면 한복남을 방문해보세요. 이곳은 전통 한정식을 현대적인 감각으로 재해석하여 제공하는 곳으로, 다양한 반찬과 함께 고급스러운 한식을 즐길 수 있습니다.
#
# 3. **목멱산방** - 남산에 위치한 목멱산방은 아름다운 경치를 감상하며 전통 한식을 맛볼 수 있는 곳입니다. 비빔밥, 불고기 등 한국을 대표하는 메뉴를 정갈하게 제공하며, 조용한 분위기에서 식사를 즐길 수 있습니다.
#
# 4. **옥동식** - 돼지국밥으로 유명한 옥동식은 전통적인 돼지국밥의 깊은 맛을 현대적으로 해석하여 제공하는 곳입니다. 깔끔하면서도 진한 국물 맛이 일품이며, 서울에서 돼지국밥을 맛보고 싶다면 추천할 만한 곳입니다.
#
# 5. **명동 교자** - 명동 교자는 칼국수와 만두로 유명한 레스토랑입니다. 특히 진한 육수와 쫄깃한 면발의 칼국수는 많은 사람들에게 사랑받고 있습니다. 전통적인 방식으로 만들어진 만두도 매우 인기 있습니다.
#
# 이 레스토랑들은 서울의 다양한 맛을 경험할 수 있는 곳으로, 각각의 특색을 잘 살린 메뉴를 제공합니다. 방문 전 예약 여부를 확인하는 것이 좋습니다.
#
# 서울은 다양한 전통과 현대적인 음식을 즐길 수 있는 곳입니다. 서울을 대표하는 음식을 맛볼 수 있는 레스토랑 다섯 곳을 추천해드릴게요.
#
# 1. **광장시장**: 전통적인 한국 길거리 음식을 맛볼 수 있는 곳으로, 특히 빈대떡과 마약김밥이 유명합니다. 시장의 활기찬 분위기 속에서 다양한 음식을 즐길 수 있습니다.
#
# 2. **한정식집 "산촌"**: 인사동에 위치한 이 레스토랑은 전통 한정식을 제공합니다. 다양한 반찬과 함께 정갈하게 차려진 한식을 경험할 수 있습니다.
#
# 3. **명동교자**: 명동에 자리한 이 식당은 칼국수와 만두로 유명합니다. 부드럽고 진한 육수가 매력적이며, 서울을 방문하는 관광객들에게 인기가 많습니다.
#
# 4. **삼청동 수제비**: 삼청동에 위치한 이곳은 수제비와 전통적인 떡볶이를 맛볼 수 있는 곳입니다. 고즈넉한 한옥 분위기를 느끼며 식사할 수 있습니다.
#
# 5. **우래옥**: 을지로에 있는 이 레스토랑은 평양냉면으로 유명합니다. 고기 육수의 깊은 맛과 쫄깃한 면발을 즐길 수 있으며, 오랜 전통을 자랑하는 곳입니다.
#
# 이 외에도 서울에는 다양한 음식을 즐길 수 있는 많은 레스토랑이 있으니, 방문 시 여러 곳을 탐방해보시길 추천드립니다.
#
# Elapsed time: 48.86 seconds

# %% [markdown]
# ## 대화 히스토리 저장하기

# %%
# !pip install -q langchain

# %% [markdown]
# ### messages에 추가해서 해결

# %%
from langchain_core.messages import SystemMessage, HumanMessage, AIMessage

messages = [
    SystemMessage(content="당신은 여행 전문가로 고객의 여행 일정에 도움을 줍니다."), 
    HumanMessage(content="부산 여행에서 딱 한 곳만을 가봐야 한다면 어떤 곳인지 알려주세요.")
]

response = llm.invoke(messages)

# %%
# 받은 응답을 messages에 추가하고, messages
messages.append(response)

# %%
# messages의 제일 마지막 요소 삭제
# del messages[-1]

# %%
# messages
for message in messages:
    print(type(message), message.content)
    # print(message.content)
# Out:
# <class 'langchain_core.messages.system.SystemMessage'> 당신은 여행 전문가로 고객의 여행 일정에 도움을 줍니다.
# <class 'langchain_core.messages.human.HumanMessage'> 부산 여행에서 딱 한 곳만을 가봐야 한다면 어떤 곳인지 알려주세요.
# <class 'langchain_core.messages.ai.AIMessage'> 부산에서 딱 한 곳만 방문해야 한다면, 해운대 해수욕장을 추천합니다. 해운대는 부산의 대표적인 해변으로, 아름다운 백사장과 맑은 바다, 그리고 주변의 현대적인 도시 풍경이 어우러져 있어 많은 관광객들에게 사랑받는 장소입니다. 해운대에서는 해수욕 뿐만 아니라 다양한 해양 스포츠를 즐길 수 있으며, 주변에는 고급 레스토랑과 카페, 쇼핑몰 등 다양한 편의시설도 잘 갖춰져 있습니다. 또한, 해운대 인근에는 동백섬과 누리마루 APEC 하우스 같은 명소도 있어 짧은 시간 안에 다양한 경험을 할 수 있습니다.

# %%
# 두번째 질문을 messages에 추가
messages.append(HumanMessage(content="부산역에서 그곳에 가는 교통편을 알려주세요."))
# messages로 llm에 요청
response = llm.invoke(messages)
# 두번째 질문에 대한 응답을 messages에 추가
messages.append(response)
# messages 결과 확인
for message in messages:
    print(type(message), message)
# Out:
# <class 'langchain_core.messages.system.SystemMessage'> content='당신은 여행 전문가로 고객의 여행 일정에 도움을 줍니다.' additional_kwargs={} response_metadata={}
# <class 'langchain_core.messages.human.HumanMessage'> content='부산 여행에서 딱 한 곳만을 가봐야 한다면 어떤 곳인지 알려주세요.' additional_kwargs={} response_metadata={}
# <class 'langchain_core.messages.ai.AIMessage'> content='부산에서 딱 한 곳만 방문해야 한다면, 해운대 해수욕장을 추천합니다. 해운대는 부산의 대표적인 해변으로, 아름다운 백사장과 맑은 바다, 그리고 주변의 현대적인 도시 풍경이 어우러져 있어 많은 관광객들에게 사랑받는 장소입니다. 해운대에서는 해수욕 뿐만 아니라 다양한 해양 스포츠를 즐길 수 있으며, 주변에는 고급 레스토랑과 카페, 쇼핑몰 등 다양한 편의시설도 잘 갖춰져 있습니다. 또한, 해운대 인근에는 동백섬과 누리마루 APEC 하우스 같은 명소도 있어 짧은 시간 안에 다양한 경험을 할 수 있습니다.' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 157, 'prompt_tokens': 49, 'total_tokens': 206, 'completion_tokens_details': {'audio_tokens': None, 'reasoning_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_45c6de4934', 'finish_reason': 'stop', 'logprobs': None} id='run-0f95b364-5da3-4818-9105-aab47726513d-0' usage_metadata={'input_tokens': 49, 'output_tokens': 157, 'total_tokens': 206, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 0}}
# <class 'langchain_core.messages.human.HumanMessage'> content='부산역에서 그곳에 가는 교통편을 알려주세요.' additional_kwargs={} response_metadata={}
# <class 'langchain_core.messages.ai.AIMessage'> content='부산역에서 해운대 해수욕장까지 가는 방법은 여러 가지가 있습니다. 가장 일반적인 대중교통 옵션을 소개하겠습니다.\n\n1. **지하철 이용:**\n   - 부산역에서 지하철 1호선을 타고 서면역에서 2호선으로 환승합니다.\n   - 2호선을 타고 해운대역에서 하차합니다. 해운대역에서 해운대 해수욕장까지는 도보로 약 10분 정도 소요됩니다.\n\n2. **버스 이용:**\n   - 부산역 앞 버스 정류장에서 1003번 버스를 탑니다.\n   - 해운대 해수욕장 정류장에서 하차합니다. 버스는 교통 상황에 따라 시간이 변동될 수 있지만 대체로 약 1시간 정도 소요됩니다.\n\n3. **택시 이용:**\n   - 택시를 이용하면 약 30-40분 정도 소요되며, 교통 상황에 따라 달라질 수 있습니다. 비용은 대략 15,000원에서 20,000원 사이로 예상됩니다.\n\n각 방법마다 장단점이 있으니 일정과 예산에 맞춰 선택하시면 좋겠습니다.' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 264, 'prompt_tokens': 230, 'total_tokens': 494, 'completion_tokens_details': {'audio_tokens': None, 'reasoning_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_a7d06e42a7', 'finish_reason': 'stop', 'logprobs': None} id='run-58c35f8e-a380-4293-913f-6c8750395063-0' usage_metadata={'input_tokens': 230, 'output_tokens': 264, 'total_tokens': 494, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 0}}

# %%
for message in messages:
    print(message)
# Out:
# content='당신은 여행 전문가로 고객의 여행 일정에 도움을 줍니다.' additional_kwargs={} response_metadata={}
# content='부산 여행에서 딱 한 곳만을 가봐야 한다면 어떤 곳인지 알려주세요.' additional_kwargs={} response_metadata={}
# content='부산에서 딱 한 곳만 방문해야 한다면, 해운대 해수욕장을 추천합니다. 해운대는 부산의 대표적인 해변으로, 아름다운 백사장과 맑은 바다, 그리고 주변의 현대적인 도시 풍경이 어우러져 있어 많은 관광객들에게 사랑받는 장소입니다. 해운대에서는 해수욕 뿐만 아니라 다양한 해양 스포츠를 즐길 수 있으며, 주변에는 고급 레스토랑과 카페, 쇼핑몰 등 다양한 편의시설도 잘 갖춰져 있습니다. 또한, 해운대 인근에는 동백섬과 누리마루 APEC 하우스 같은 명소도 있어 짧은 시간 안에 다양한 경험을 할 수 있습니다.' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 157, 'prompt_tokens': 49, 'total_tokens': 206, 'completion_tokens_details': {'audio_tokens': None, 'reasoning_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_45c6de4934', 'finish_reason': 'stop', 'logprobs': None} id='run-0f95b364-5da3-4818-9105-aab47726513d-0' usage_metadata={'input_tokens': 49, 'output_tokens': 157, 'total_tokens': 206, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 0}}
# content='부산역에서 그곳에 가는 교통편을 알려주세요.' additional_kwargs={} response_metadata={}
# content='부산역에서 해운대 해수욕장까지 가는 방법은 여러 가지가 있습니다. 가장 일반적인 대중교통 옵션을 소개하겠습니다.\n\n1. **지하철 이용:**\n   - 부산역에서 지하철 1호선을 타고 서면역에서 2호선으로 환승합니다.\n   - 2호선을 타고 해운대역에서 하차합니다. 해운대역에서 해운대 해수욕장까지는 도보로 약 10분 정도 소요됩니다.\n\n2. **버스 이용:**\n   - 부산역 앞 버스 정류장에서 1003번 버스를 탑니다.\n   - 해운대 해수욕장 정류장에서 하차합니다. 버스는 교통 상황에 따라 시간이 변동될 수 있지만 대체로 약 1시간 정도 소요됩니다.\n\n3. **택시 이용:**\n   - 택시를 이용하면 약 30-40분 정도 소요되며, 교통 상황에 따라 달라질 수 있습니다. 비용은 대략 15,000원에서 20,000원 사이로 예상됩니다.\n\n각 방법마다 장단점이 있으니 일정과 예산에 맞춰 선택하시면 좋겠습니다.' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 264, 'prompt_tokens': 230, 'total_tokens': 494, 'completion_tokens_details': {'audio_tokens': None, 'reasoning_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_a7d06e42a7', 'finish_reason': 'stop', 'logprobs': None} id='run-58c35f8e-a380-4293-913f-6c8750395063-0' usage_metadata={'input_tokens': 230, 'output_tokens': 264, 'total_tokens': 494, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 0}}

# %%
# 마지막 질문에 대한 응답 결과를 messages에서 확인하기

print(messages[-1].content)
# Out:
# 부산역에서 해운대 해수욕장까지 가는 방법은 여러 가지가 있습니다. 가장 일반적인 대중교통 옵션을 소개하겠습니다.
#
# 1. **지하철 이용:**
#    - 부산역에서 지하철 1호선을 타고 서면역에서 2호선으로 환승합니다.
#    - 2호선을 타고 해운대역에서 하차합니다. 해운대역에서 해운대 해수욕장까지는 도보로 약 10분 정도 소요됩니다.
#
# 2. **버스 이용:**
#    - 부산역 앞 버스 정류장에서 1003번 버스를 탑니다.
#    - 해운대 해수욕장 정류장에서 하차합니다. 버스는 교통 상황에 따라 시간이 변동될 수 있지만 대체로 약 1시간 정도 소요됩니다.
#
# 3. **택시 이용:**
#    - 택시를 이용하면 약 30-40분 정도 소요되며, 교통 상황에 따라 달라질 수 있습니다. 비용은 대략 15,000원에서 20,000원 사이로 예상됩니다.
#
# 각 방법마다 장단점이 있으니 일정과 예산에 맞춰 선택하시면 좋겠습니다.

# %%
messages.append(HumanMessage(content="그 근처에 먹을 만한 음식점들을 추천해주세요."))
response = llm.invoke(messages)
messages.append(response)
for message in messages:
    print(type(message), message)
# Out:
# <class 'langchain_core.messages.system.SystemMessage'> content='당신은 여행 전문가로 고객의 여행 일정에 도움을 줍니다.' additional_kwargs={} response_metadata={}
# <class 'langchain_core.messages.human.HumanMessage'> content='부산 여행에서 딱 한 곳만을 가봐야 한다면 어떤 곳인지 알려주세요.' additional_kwargs={} response_metadata={}
# <class 'langchain_core.messages.ai.AIMessage'> content='부산에서 딱 한 곳만 가봐야 한다면 해운대를 추천합니다. 해운대는 부산을 대표하는 해변으로, 아름다운 해변 경치와 함께 다양한 레스토랑, 카페, 상점들이 있어 볼거리와 즐길 거리가 풍부합니다. 해운대 해수욕장에서 여유로운 시간을 보내고, 해운대 바다를 배경으로 멋진 사진도 남길 수 있습니다. 또한, 해운대 주변에 위치한 동백섬과 누리마루 APEC 하우스를 방문해보는 것도 좋은 선택입니다. 이곳은 자연과 현대 건축물이 어우러져 독특한 매력을 자아냅니다.' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 150, 'prompt_tokens': 49, 'total_tokens': 199, 'completion_tokens_details': {'audio_tokens': None, 'reasoning_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_a7d06e42a7', 'finish_reason': 'stop', 'logprobs': None} id='run-065d9710-05d0-439b-bf61-e45e4e3e6d26-0' usage_metadata={'input_tokens': 49, 'output_tokens': 150, 'total_tokens': 199, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 0}}
# <class 'langchain_core.messages.human.HumanMessage'> content='부산역에서 그곳에 가는 교통편을 알려주세요.' additional_kwargs={} response_metadata={}
# <class 'langchain_core.messages.ai.AIMessage'> content='부산역에서 해운대까지 가는 방법은 여러 가지가 있지만, 가장 일반적인 대중교통 수단은 지하철입니다. 다음은 지하철을 이용한 경로입니다.\n\n1. **지하철 1호선 이용**: 부산역에서 1호선을 타고 서면역으로 이동합니다.\n2. **서면역 환승**: 서면역에서 2호선(장산 방면)으로 환승합니다.\n3. **해운대역 도착**: 2호선을 타고 해운대역에서 하차합니다. \n\n해운대역에서 해운대 해수욕장까지는 도보로 약 10~15분 정도 걸리며, 역 주변에는 안내 표지판이 잘 되어 있어 쉽게 찾으실 수 있습니다.\n\n또한, 택시를 이용하실 경우 약 30~40분 정도 소요되며, 교통 상황에 따라 시간이 달라질 수 있습니다. 택시는 지하철보다 편리하지만 비용이 조금 더 들 수 있다는 점 참고하시기 바랍니다.' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 233, 'prompt_tokens': 223, 'total_tokens': 456, 'completion_tokens_details': {'audio_tokens': None, 'reasoning_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_45c6de4934', 'finish_reason': 'stop', 'logprobs': None} id='run-609104a5-966e-43d5-8e54-38795275ef63-0' usage_metadata={'input_tokens': 223, 'output_tokens': 233, 'total_tokens': 456, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 0}}
# <class 'langchain_core.messages.human.HumanMessage'> content='그 근처에 먹을 만한 음식점들을 추천해주세요.' additional_kwargs={} response_metadata={}
# <class 'langchain_core.messages.ai.AIMessage'> content="해운대 주변에는 다양한 음식점들이 있어 선택의 폭이 넓습니다. 몇 가지 추천드리자면:\n\n1. **밀면**: 부산의 대표적인 음식인 밀면을 맛볼 수 있는 곳으로 '할매가야밀면'이 유명합니다. 시원하고 쫄깃한 면발이 특징입니다.\n\n2. **횟집**: 해운대 해수욕장 근처에는 신선한 회를 맛볼 수 있는 횟집이 많이 있습니다. '해운대 암소갈비'는 회뿐만 아니라 고기도 함께 즐길 수 있는 곳입니다.\n\n3. **돼지국밥**: 부산을 대표하는 음식 중 하나인 돼지국밥을 맛보려면 '원조할매돼지국밥'을 추천합니다. 깊고 진한 국물이 일품입니다.\n\n4. **해산물 요리**: 해산물 요리를 좋아하신다면 '해운대 시장' 내의 다양한 해산물 음식점들을 둘러보세요. 저렴한 가격에 다양한 해산물 요리를 즐길 수 있습니다.\n\n5. **카페**: 해운대 바닷가 근처에는 멋진 뷰를 자랑하는 카페들도 많이 있습니다. '더베이 101'은 특히 야경이 아름다워 저녁 시간대에 방문하기 좋습니다.\n\n이 외에도 해운대 지역은 다양한 종류의 음식점이 밀집해 있어 취향에 맞는 곳을 쉽게 찾으실 수 있습니다." additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 331, 'prompt_tokens': 478, 'total_tokens': 809, 'completion_tokens_details': {'audio_tokens': None, 'reasoning_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_45c6de4934', 'finish_reason': 'stop', 'logprobs': None} id='run-455a0f8a-5f7f-4e18-8709-b2f289d4bc07-0' usage_metadata={'input_tokens': 478, 'output_tokens': 331, 'total_tokens': 809, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 0}}

# %% [markdown]
# ## langchain history로 해결하는 방법

# %%
# %pip install -q langchain_community

# %%
# gpt-3.5 모델로 실습하기 
# https://platform.openai.com/docs/models/o1
from langchain_openai import ChatOpenAI
llm = ChatOpenAI(model="gpt-3.5-turbo-0125", api_key=api_key)
llm
# Out:
# ChatOpenAI(client=<openai.resources.chat.completions.Completions object at 0x000002A679858110>, async_client=<openai.resources.chat.completions.AsyncCompletions object at 0x000002A67985B2C0>, root_client=<openai.OpenAI object at 0x000002A6797CFE60>, root_async_client=<openai.AsyncOpenAI object at 0x000002A67985BD40>, model_name='gpt-3.5-turbo-0125', model_kwargs={}, openai_api_key=SecretStr('**********'))

# %%
from langchain.memory import ChatMessageHistory

history = ChatMessageHistory()
history.add_message(
    SystemMessage(content="당신은 서울의 음시과 문화 전문가 입니다.")
)
history.add_user_message("서울을 대표하는 음식을 맛볼 수 있는 레스토랑 5개를 추천해줘.")
response = llm.invoke(history.messages)

# %%
print(response)
# Out:
# content='서울을 대표하는 음식을 맛볼 수 있는 레스토랑 5개를 추천해드리겠습니다.\n\n1. 남대문시장 곱창골목 - 남대문시장 내에 위치한 곱창 전문 음식점들이 모여 있는 곳으로, 한국 전통 음식인 곱창을 맛볼 수 있습니다.\n\n2. 광장시장 생선구이 - 광장시장은 대표적인 전통시장으로 유명하며, 생선구이 전문 음식점들이 많이 있습니다. 신선한 해산물을 맛볼 수 있는 곳입니다.\n\n3. 이화동 곰탕 - 이화동에 위치한 곰탕 전문 음식점들은 한국 전통 음식 중 하나인 곰탕을 맛볼 수 있는 곳으로 유명합니다.\n\n4. 인사동 분식집 - 인사동은 한국 전통 문화가 살아있는 곳으로, 전통 분식을 맛볼 수 있는 분식집들이 많이 있습니다.\n\n5. 강남 냉면집 - 강남 지역에는 맛있는 냉면집들이 많이 있습니다. 한국의 여름 대표 음식인 냉면을 맛볼 수 있는 곳을 추천드립니다.\n\n이곳들을 방문하면 서울의 다양한 음식 문화를 경험할 수 있을 것입니다.' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 422, 'prompt_tokens': 68, 'total_tokens': 490, 'completion_tokens_details': {'audio_tokens': None, 'reasoning_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 0}}, 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'finish_reason': 'stop', 'logprobs': None} id='run-52fcd0e3-6d26-4d4c-bb36-f94a3bd52da0-0' usage_metadata={'input_tokens': 68, 'output_tokens': 422, 'total_tokens': 490, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 0}}

# %%
print(response.content)
# Out:
# 서울은 다양한 전통과 현대적인 음식을 맛볼 수 있는 곳으로, 다양한 레스토랑이 있습니다. 다음은 서울을 대표하는 음식을 맛볼 수 있는 레스토랑 5곳을 추천드립니다.
#
# 1. **광장시장**:
#    - 광장시장은 전통적인 한국 음식들을 맛볼 수 있는 곳으로, 특히 빈대떡, 마약김밥, 육회 등이 유명합니다. 시장 내의 다양한 노점과 작은 식당에서 전통적인 맛을 즐길 수 있습니다.
#
# 2. **진주회관**:
#    - 진주회관은 한국 전통 음식인 콩나물국밥으로 유명한 곳입니다. 콩나물국밥은 해장 음식으로도 잘 알려져 있으며, 진주회관은 그 중에서도 오랜 전통을 자랑합니다.
#
# 3. **산촌**:
#    - 산촌은 전통 한식당으로, 다양한 종류의 한식을 코스로 즐길 수 있습니다. 특히, 정갈한 반찬과 전통적인 한식 요리를 고급스럽게 제공하여 한국의 맛을 경험하기에 좋습니다.
#
# 4. **부암동 연경**:
#    - 부암동에 위치한 연경은 전통적인 한정식을 제공하는 곳입니다. 이곳에서는 계절마다 신선한 재료로 만든 다양한 한식 요리를 맛볼 수 있습니다. 고즈넉한 분위기 속에서 한국의 전통 음식을 경험할 수 있습니다.
#
# 5. **한미리**:
#    - 한미리는 비빔밥과 불고기 등 한식을 고급스럽게 재해석하여 제공하는 레스토랑입니다. 다양한 비빔밥 메뉴와 함께 전통적인 맛을 현대적으로 즐길 수 있는 곳입니다.
#
# 이 외에도 서울에는 수많은 전통과 현대의 맛을 결합한 레스토랑이 많으니, 다양한 장소를 탐방하며 서울의 맛을 경험해보시길 권장합니다.

# %%
history.add_user_message("부산역에서 그곳에 가는 교통편을 알려주세요.")
response = llm.invoke(history.messages)
history.add_ai_message(response.content)
for message in history.messages:
    print(type(message), message)
# Out:
# <class 'langchain_core.messages.system.SystemMessage'> content='당신은 서울의 음시과 문화 전문가 입니다.' additional_kwargs={} response_metadata={}
# <class 'langchain_core.messages.human.HumanMessage'> content='서울을 대표하는 음식을 맛볼 수 있는 레스토랑 5개를 추천해줘.' additional_kwargs={} response_metadata={}
# <class 'langchain_core.messages.human.HumanMessage'> content='부산역에서 그곳에 가는 교통편을 알려주세요.' additional_kwargs={} response_metadata={}
# <class 'langchain_core.messages.ai.AIMessage'> content='서울을 대표하는 음식을 맛볼 수 있는 레스토랑을 몇 군데 추천해드릴게요. 그리고 부산역에서 해당 레스토랑으로 가는 교통편도 안내해드리겠습니다.\n\n1. **광장시장** - 빈대떡, 마약김밥 등 다양한 전통 시장 음식을 맛볼 수 있습니다.\n   - **가장 빠른 교통편**: 부산역에서 KTX를 타고 서울역으로 이동(약 2시간 30분 소요)한 후, 서울역에서 지하철 1호선을 타고 종로3가역에서 하차하여 도보로 약 10분 이동.\n\n2. **명동교자** - 칼국수와 만두로 유명한 곳입니다.\n   - **가장 빠른 교통편**: 부산역에서 KTX를 타고 서울역으로 이동 후, 서울역에서 지하철 4호선을 타고 명동역에서 하차하여 도보로 약 5분 이동.\n\n3. **진미식당** - 육회비빔밥으로 유명한 전통 한식당입니다.\n   - **가장 빠른 교통편**: 부산역에서 KTX를 타고 서울역으로 이동 후, 서울역에서 지하철 4호선을 타고 회현역에서 하차하여 도보로 약 10분 이동.\n\n4. **토속촌 삼계탕** - 삼계탕으로 유명한 곳입니다.\n   - **가장 빠른 교통편**: 부산역에서 KTX를 타고 서울역으로 이동 후, 서울역에서 지하철 3호선을 타고 경복궁역에서 하차하여 도보로 약 5분 이동.\n\n5. **마포 돼지갈비** - 한국식 돼지갈비를 맛볼 수 있는 곳입니다.\n   - **가장 빠른 교통편**: 부산역에서 KTX를 타고 서울역으로 이동 후, 서울역에서 지하철 5호선을 타고 마포역에서 하차하여 도보로 약 10분 이동.\n\n각 레스토랑은 서울의 대표적인 음식을 맛볼 수 있는 곳으로, 전통의 맛을 느끼기에 적합합니다. KTX는 빠르고 편리한 이동 수단이니, 서울역을 기점으로 지하철을 이용하면 쉽게 접근할 수 있습니다.' additional_kwargs={} response_metadata={}

# %% [markdown]
# # 토큰수 확인

# %%
from langchain.callbacks import get_openai_callback

with get_openai_callback() as callback:
    message = [HumanMessage(content="서울역에 도착해서 서울에서 광장시장까지 가는 교통편 3개를 알려줘")]
    reaponse = llm.invoke(message)
    print(reaponse.content)
    print("-"*20)
    print(callback)
    print("-"*20)
    print(callback.total_tokens)
# Out:
# 1. 지하철
# - 서울역에서 4호선을 타고 혜화역까지 이동
# - 혜화역에서 4호선을 환승하여 동대문역으로 이동
# - 동대문역에서 1호선을 타고 종로5가역까지 이동
# - 종로5가역에서 광장시장까지 도보로 이동
#
# 2. 버스
# - 서울역 버스 정류장에서 273번 버스를 타고 종로4가 정류장에서 하차
# - 종로4가에서 도보로 광장시장까지 이동
#
# 3. 택시
# - 서울역 택시 승강장에서 택시를 타고 광장시장까지 이동 (약 10분 소요)
# --------------------
# Tokens Used: 275
# 	Prompt Tokens: 51
# 	Completion Tokens: 224
# Successful Requests: 1
# Total Cost (USD): $0.00036150000000000006
# --------------------
# 275

# %% [markdown]
# ### ConversationBufferMemory로 히스토리 기록
